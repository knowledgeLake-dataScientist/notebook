# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread('images/lung-color.jpg',cv2.IMREAD_COLOR)

# %%
cv2.imshow('image',img1)

# %%
cv2.waitKey(0)
# Out:
# 255

# %%
img = cv2.imread('images/lung-color.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('image',img)

# %%
cv2.waitKey(0)
# Out:
# 255

# %%
cv2.destroyAllWindows()

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.plot([550,420],[100,600], 'c', linewidth=3)

# %%
plt.show()

# %%
cv2.imwrite('update-lung-gray.jpg',img)
# Out:
# True
